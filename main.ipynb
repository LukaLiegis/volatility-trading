# %%
from volatilitymodels import VolModel

# %%
import yfinance as yf
df = yf.download("AAPL", period="1y")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Close = df.Close

# %%
vol = VolModel().parkinson(data=df)
# Out:
# Initializing VolModel

# %%
print(vol)
# Out:
# Date
# 2023-05-01    0.003377
# 2023-05-02    0.003318
# 2023-05-03    0.003354
# 2023-05-04    0.003254
# 2023-05-05    0.003217
#                 ...
# 2024-03-12    0.003704
# 2024-03-13    0.003641
# 2024-03-14    0.003631
# 2024-03-15    0.003612
# 2024-03-18    0.003221
# Length: 222, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(vol, label="Volatility")
